# %% [markdown]
# # Working with Server
#
# > Status: **EXPERIMENTAL**
#
# It's possible to start Frictionless API as a standalone server.

# %% [markdown]
# ```sh
# !pip install frictionless[server]
# ```

# %% [markdown]
# ## Running API Server

# %% [markdown]
# ```sh
# $ frictionless api
# ```
